# %% [markdown]
# <a href="https://colab.research.google.com/github/mun387344/insurance-prediction-logistic-regression/blob/main/MyLogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("/content/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'], df['bought_insurance'], color='red')
plt.xlabel('Age')
plt.ylabel('Bought Insurance')
plt.title('Age vs Insurance Purchase')
plt.show()

# %%
df.shape
# Out:
# (27, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df[['age']],
    df['bought_insurance'],
    test_size=0.1,
    random_state=42
)

# %%
#Let's check
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24, 1)
# (3, 1)
# (24,)
# (3,)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(X_test)
# Out:
#     age
# 0    22
# 13   29
# 10   18

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1])

# %%
#Evaluate Accuracy
model.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %%
model.predict_proba(X_test)
# Out:
# array([[0.87602584, 0.12397416],
#        [0.74722033, 0.25277967],
#        [0.92080326, 0.07919674]])

# %%
model.predict([[52]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
